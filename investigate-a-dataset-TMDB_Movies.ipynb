# %% [markdown]
# # Investigating (Movies Database!)
#
# ## Table of Contents

# %% [markdown]
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
# This data set contains information about 10,000 movies collected from The Movie Database (TMDb), including user ratings and revenue.
# <ul>
# <li>Certain columns, like ‘cast’ and ‘genres’, contain multiple values separated by pipe (|) characters.</li>
# <li>There are some odd characters in the ‘cast’ column.</li>
# <li>Don’t worry about cleaning them.</li>
# <li>You can leave them as is.</li>
# <li>The final two columns ending with “_adj” show the budget and revenue of the associated movie in terms of 2010 dollars, accounting for inflation over time.</li>
# </ul>

# %% [markdown]
# ### The questions we will investigate in this project are:
# <ul>
#     <li>How many movies released every 10 years (decades)?</li>
#     <li>What are the movies which had most and least profit?</li>
#     <li>What are the movies with largest and lowest budgets?</li>
#     <li>What are the movies with most and least earned revenue?v
#     <li>What are the movies with highest and lowest vote counts?</li>
#     <li>What are the movies with the highest and lowest vote average?</li>
#     <li>What are the movies with longest and shortest runtime?</li>
#     <li>What are the movies average runtime of the movies?</li>
#     <li>What is the historical Profitability through the years?</li>
#     <li>What are the most and least profit years?</li>
#     <li>What are the movies with 50M or more profit?</li>
#     <li>What are the top 10 succesful Production Companies?</li>
#     <li>What are the top 10 succesful Director?</li>
#     <li>What are the top 10 succesful Genres?</li>
#     <li>What are the top 10 succesful Stars from Cast?</li>
# </ul>

# %% [markdown]
# ### The First step is to import libraries as we need on this project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# In this section of the project we will load, check, trim, and clean the database.

# %% [markdown]
# ### General Properties

# %% [markdown]
# Here we loaded the database to be readable in the project

# %%
df = pd.read_csv("tmdb-movies.csv")
# This file doesn't contain duplicated records, so I have duplicate the file
# with some duplicated values in order to check the function
# df = pd.read_csv("noshowappointments-kagglev2-may-2016_DuplicationTest.csv")

# %% [markdown]
# Loading the first 3 rows in the database

# %%
df.head(3)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline  ...  \
# 0           The park is open.  ...
# 1          What a Lovely Day.  ...
# 2  One Choice Can Destroy You  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
#
# [3 rows x 21 columns]

# %% [markdown]
# Loading the last 3 rows in the database

# %%
df.tail(3)
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10863       Beregis Avtomobilya
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      NaN
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
#                director                                       tagline  ...  \
# 10863    Eldar Ryazanov                                           NaN  ...
# 10864       Woody Allen                     WOODY ALLEN STRIKES BACK!  ...
# 10865  Harold P. Warren  It's Shocking! It's Beyond Your Imagination!  ...
#
#                                                 overview runtime  \
# 10863  An insurance agent who moonlights as a carthie...      94
# 10864  In comic Woody Allen's film debut, he took the...      80
# 10865  A family gets lost on the road and stumbles up...      74
#
#                genres     production_companies release_date vote_count  \
# 10863  Mystery|Comedy                  Mosfilm       1/1/66         11
# 10864   Action|Comedy  Benedict Pictures Corp.      11/2/66         22
# 10865          Horror                Norm-Iris     11/15/66         15
#
#        vote_average  release_year     budget_adj  revenue_adj
# 10863           6.5          1966       0.000000          0.0
# 10864           5.4          1966       0.000000          0.0
# 10865           1.5          1966  127642.279154          0.0
#
# [3 rows x 21 columns]

# %% [markdown]
# Getting the count of records and columns in the database

# %%
# Get the count on culomns and records in the database.
rows_count, columns_count = df.shape
print("This database contains the count of {:,} Columns for {:,} Records.".format(columns_count,rows_count))
# Out:
# This database contains the count of 21 Columns for 10,866 Records.

# %% [markdown]
# Getting the count of duplicated records in the database

# %%
# Check duplications in the database, and count them.
duplicated = df.duplicated().sum()
if duplicated == 0:
    print("This database doesn't contain any Duplicated Records.")
elif duplicated == 1:
    print("This database contain only {:,} Duplicated Record.".format(duplicated))
elif duplicated > 1:
    print("This database contain only {:,} Duplicated Records.".format(duplicated))
# Out:
# This database contain only 1 Duplicated Record.

# %% [markdown]
# Getting the count of unique records in this database.

# %%
# Check how many movies have records in this database.
unique_imdb_id = df['imdb_id'].nunique()
print("This database contain the sum of {:,} unique imdb id.".format(unique_imdb_id))
# Out:
# This database contain the sum of 10,855 unique imdb id.

# %% [markdown]
# Getting the count of duplicated by imdb id

# %%
# Check how many duplicated movies in this database.
duplicated_imdb_id = df['imdb_id'].duplicated().sum()
print("This database contain the sum of {:,} duplicated imdb id.".format(duplicated_imdb_id))
# Out:
# This database contain the sum of 10 duplicated imdb id.

# %% [markdown]
# Getting list of duplicated and sorted by imdb id

# %%
df.sort_values('imdb_id', inplace = True)
bool_series1 = df["imdb_id"].duplicated()
df[bool_series1]
# Out:
#           id    imdb_id  popularity    budget  revenue  \
# 2089   42194  tt0411951    0.596430  30000000   967000
# 997   287663        NaN    0.330431         0        0
# 1528   15257        NaN    0.607851         0        0
# 1750  101907        NaN    0.256975         0        0
# 2401   45644        NaN    0.067753         0        0
# 4797  369145        NaN    0.167501         0        0
# 4872  269177        NaN    0.090552         0        0
# 6071  279954        NaN    0.004323       500        0
# 7527   50127        NaN    0.570337         0        0
# 7809   50128        NaN    0.060795         0        0
#
#                                        original_title  \
# 2089                                           TEKKEN
# 997              Star Wars Rebels: Spark of Rebellion
# 1528                               Hulk vs. Wolverine
# 1750                                    Hulk vs. Thor
# 2401  Opeth: In Live Concert At The Royal Albert Hall
# 4797                          Doctor Who: The Snowmen
# 4872                                      Party Bercy
# 6071                                 Portal: Survive!
# 7527                              Fallen: The Journey
# 7809                              Fallen: The Destiny
#
#                                                    cast  \
# 2089  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...
# 997   Freddie Prinze Jr.|Vanessa Marshall|Steve Blum...
# 1528  Fred Tatasciore|Bryce Johnson|Steve Blum|Nolan...
# 1750  Graham McTavish|Fred Tatasciore|Matthew Wolf|J...
# 2401  Mikael Ã…kerfeldt|Martin "Axe" Axenrot|Martin ...
# 4797  Matt Smith|Jenna Coleman|Richard E. Grant|Ian ...
# 4872                                   Florence Foresti
# 6071                    Monique Blanchard|Bradley Mixon
# 7527  Paul Wesley|Fernanda Andrade|Tom Skerritt|Rick...
# 7809  Paul Wesley|Fernanda Andrade|Tom Skerritt|Rick...
#
#                                                homepage  \
# 2089                                                NaN
# 997                                                 NaN
# 1528                                                NaN
# 1750                                                NaN
# 2401                               http://www.opeth.com
# 4797                                                NaN
# 4872                                                NaN
# 6071  https://www.kickstarter.com/projects/colinandc...
# 7527                                                NaN
# 7809                                                NaN
#
#                           director  \
# 2089              Dwight H. Little
# 997      Steward Lee|Steven G. Lee
# 1528                    Frank Paur
# 1750                       Sam Liu
# 2401                           NaN
# 4797                           NaN
# 4872                           NaN
# 6071  Connor McGuire|Colin McGuire
# 7527                Mikael Salomon
# 7809                Mikael Salomon
#
#                                                 tagline  ...  \
# 2089                                Survival is no game  ...
# 997                                                 NaN  ...
# 1528                                                NaN  ...
# 1750                   A Battle Between God and Monster  ...
# 2401  The Loyal Disharmonic Orchestra, Conducted By ...  ...
# 4797                                                NaN  ...
# 4872                                                NaN  ...
# 6071                                  The Cake is a Lie  ...
# 7527                                                NaN  ...
# 7809                                                NaN  ...
#
#                                                overview runtime  \
# 2089  In the year of 2039, after World Wars destroy ...      92
# 997   A Long Time Ago In A Galaxy Far, Far Awayâ€¦ A...      44
# 1528  Department H sends in Wolverine to track down ...      38
# 1750  For ages, Odin has protected his kingdom of As...      41
# 2401  As part of the ongoing celebration of their 20...     163
# 4797  Christmas Eve, 1892, and the falling snow is t...      60
# 4872  Florence Foresti is offered Bercy tribute to a...     120
# 6071  A short, live action fan film by Collin and Co...       7
# 7527  A year later, Aaron is still traveling around ...      80
# 7809  Aaron and Azazel defeat the Powers, and force ...      80
#
#                                               genres    production_companies  \
# 2089     Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
# 997                                              NaN                     NaN
# 1528                Animation|Action|Science Fiction          Marvel Studios
# 1750        Action|Animation|Fantasy|Science Fiction          Marvel Studios
# 2401                                           Music                     NaN
# 4797                                             NaN       BBC Television UK
# 4872                                          Comedy              TF1 VidÃ©o
# 6071                          Action|Science Fiction                     NaN
# 7527           Action|Adventure|Drama|Fantasy|Family                     NaN
# 7809  Adventure|Fantasy|Drama|Action|Science Fiction                     NaN
#
#      release_date vote_count  vote_average  release_year    budget_adj  \
# 2089      3/20/10        110           5.0          2010  3.000000e+07
# 997       10/3/14         13           6.8          2014  0.000000e+00
# 1528      1/27/09         38           6.9          2009  0.000000e+00
# 1750      1/27/09         38           6.4          2009  0.000000e+00
# 2401      9/21/10         10           8.6          2010  0.000000e+00
# 4797     12/25/12         10           7.8          2012  0.000000e+00
# 4872      9/23/12         15           6.4          2012  0.000000e+00
# 6071      10/8/13         11           7.5          2013  4.680167e+02
# 7527       1/1/07         11           7.3          2007  0.000000e+00
# 7809       1/1/07         13           7.0          2007  0.000000e+00
#
#       revenue_adj
# 2089     967000.0
# 997           0.0
# 1528          0.0
# 1750          0.0
# 2401          0.0
# 4797          0.0
# 4872          0.0
# 6071          0.0
# 7527          0.0
# 7809          0.0
#
# [10 rows x 21 columns]

# %% [markdown]
# Getting list of duplicated and sorted by id

# %%
df.sort_values('id', inplace = True)
bool_series2 = df['id'].duplicated()
df[bool_series2]
# Out:
#          id    imdb_id  popularity    budget  revenue original_title  \
# 2090  42194  tt0411951     0.59643  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline  ...  \
# 2090  Dwight H. Little  Survival is no game  ...
#
#                                                overview runtime  \
# 2090  In the year of 2039, after World Wars destroy ...      92
#
#                                            genres    production_companies  \
# 2090  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
#
#      release_date vote_count  vote_average  release_year  budget_adj  \
# 2090      3/20/10        110           5.0          2010  30000000.0
#
#       revenue_adj
# 2090     967000.0
#
# [1 rows x 21 columns]

# %% [markdown]
# Analyzing and Summarizing the findings for duplication in the database

# %%
# Check if the sum of the unique, and duplicated imdb ids are the same as records count.
if rows_count == unique_imdb_id + duplicated_imdb_id + duplicated:
    print('There are {:,} records in this database as below breakdown:\n >> {:,} unique imdb id\n \
>> {:,} duplicated records for those same imdb id\n >> {} duplicated \
row'.format(rows_count, unique_imdb_id, duplicated_imdb_id, duplicated))
elif rows_count != unique_imdb_id + duplicated_imdb_id:
    print('There is something wrong in this calculations as the records are not matching with \
the sum of the duplicate and unique records.')
# Out:
# There are 10,866 records in this database as below breakdown:
#  >> 10,855 unique imdb id
#  >> 10 duplicated records for those same imdb id
#  >> 1 duplicated row

# %%
# Check how duplicated movies with the same data in this database.
duplicated_movies = df.duplicated(['imdb_id','original_title']).sum()
print("This database contains the sum of {:,} movies.".format(duplicated_movies))
# Out:
# This database contains the sum of 1 movies.

# %% [markdown]
# Inspecting for missing values in the database

# %%
# Inspection for missing values or any issue to be handled.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10866 entries, 8088 to 3460
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
#  15  release_date          10866 non-null  object
#  16  vote_count            10866 non-null  int64
#  17  vote_average          10866 non-null  float64
#  18  release_year          10866 non-null  int64
#  19  budget_adj            10866 non-null  float64
#  20  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.8+ MB

# %% [markdown]
# ### Overview Findings on the database

# %% [markdown]
# <ul>
# <li>9 records without imdb_id.</li>
# <li>1 record is duplicated.</li>
# <li>Minimal records without Cast, director, overview, or generes.</li>
# <li>Too many records without homepage, tagline, keywords, or production companies</li>
# </ul>

# %% [markdown]
# Getting some information and statictics about the database like the Count, Mean, Min, Max, ... etc

# %%
# Getting some information and statictics about the database
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# std      575.619058      0.935142     12.812941  3.430616e+07  1.446325e+08
# min       10.000000      1.500000   1960.000000  0.000000e+00  0.000000e+00
# 25%       17.000000      5.400000   1995.000000  0.000000e+00  0.000000e+00
# 50%       38.000000      6.000000   2006.000000  0.000000e+00  0.000000e+00
# 75%      145.750000      6.600000   2011.000000  2.085325e+07  3.369710e+07
# max     9767.000000      9.200000   2015.000000  4.250000e+08  2.827124e+09

# %% [markdown]
# The oldest movie released on the year 1960, and the last released one in this database released on 2015.
# Average duration of the movies is 102 minutes.
# Average votes count is 217 for the movies, while the maximum is 9,767 votes, and the minimum is only 10 votes.

# %%
# Find the most voted movie.
mask=df.query('vote_count == 9767')
mask
# Out:
#          id    imdb_id  popularity     budget    revenue original_title  \
# 1919  27205  tt1375666    9.363643  160000000  825500000      Inception
#
#                                                    cast  \
# 1919  Leonardo DiCaprio|Joseph Gordon-Levitt|Ellen P...
#
#                                    homepage           director  \
# 1919  http://inceptionmovie.warnerbros.com/  Christopher Nolan
#
#                                    tagline  ...  \
# 1919  Your mind is the scene of the crime.  ...
#
#                                                overview runtime  \
# 1919  Cobb, a skilled thief who commits corporate es...     148
#
#                                                  genres  \
# 1919  Action|Thriller|Science Fiction|Mystery|Adventure
#
#                          production_companies release_date vote_count  \
# 1919  Legendary Pictures|Warner Bros.|Syncopy      7/14/10       9767
#
#       vote_average  release_year   budget_adj  revenue_adj
# 1919           7.9          2010  160000000.0  825500000.0
#
# [1 rows x 21 columns]

# %%
# Find the least voted movies.
mask=df.query('vote_count == 10')
mask
# Out:
#            id    imdb_id  popularity   budget  revenue  \
# 7204       26  tt0352994    0.192215  1400000        0
# 10134     248  tt0055312    0.290285  2900000  5000000
# 6957      286  tt0853060    0.013578        0        0
# 10450     751  tt0057334    0.628520        0        0
# 9891      758  tt0058382    0.371976        0        0
# ...       ...        ...         ...      ...      ...
# 572    365717  tt4016250    0.082569        0        0
# 528    369058  tt5210380    0.133921        0        0
# 4797   369145        NaN    0.167501        0        0
# 569    371833  tt4974584    0.088764        0        0
# 6078   376823  tt3231100    0.002647        0        0
#
#                         original_title  \
# 7204                LaLehet Al HaMayim
# 10134            Pocketful of Miracles
# 6957   Deutschland. Ein SommermÃ¤rchen
# 10450             Murder at the Gallop
# 9891                       Murder Ahoy
# ...                                ...
# 572                       The Audition
# 528                      Merry Kissmas
# 4797           Doctor Who: The Snowmen
# 569          Harry Price: Ghost Hunter
# 6078                       Trophy Kids
#
#                                                     cast  \
# 7204   Lior Ashkenazi|Knut Berger|Caroline Peters|Gid...
# 10134  Glenn Ford|Bette Davis|Hope Lange|Arthur O'Con...
# 6957   Jens Lehmann|Arne Friedrich|Philipp Lahm|Torst...
# 10450  Margaret Rutherford|Stringer Davis|Robert Morl...
# 9891   Margaret Rutherford|Stringer Davis|Lionel Jeff...
# ...                                                  ...
# 572    Leonardo DiCaprio|Brad Pitt|Robert De Niro|Mar...
# 528    Karissa Staples|Brant Daugherty|Brittany Under...
# 4797   Matt Smith|Jenna Coleman|Richard E. Grant|Ian ...
# 569    Rafe Spall|Cara Theobold|Tom Ward|Sophie Stant...
# 6078                                                 NaN
#
#                               homepage         director  \
# 7204   http://www.walkonwatermovie.com        Eytan Fox
# 10134                              NaN      Frank Capra
# 6957                               NaN  SÃ¶nke Wortmann
# 10450                              NaN   George Pollock
# 9891                               NaN   George Pollock
# ...                                ...              ...
# 572                                NaN  Martin Scorsese
# 528                                NaN   Michael Feifer
# 4797                               NaN              NaN
# 569                                NaN      Alex Pillai
# 6078                               NaN       Chris Bell
#
#                                               tagline  ...  \
# 7204   He was trained to hate until he met the enemy.  ...
# 10134               You have to see it to believe it!  ...
# 6957                                              NaN  ...
# 10450      It's a Penny to a Pony... Murder Will Out!  ...
# 9891            New mischief amidst the mizzen-masts!  ...
# ...                                               ...  ...
# 572                       A short film with big egos.  ...
# 528                                               NaN  ...
# 4797                                              NaN  ...
# 569                                               NaN  ...
# 6078                                              NaN  ...
#
#                                                 overview runtime  \
# 7204   Eyal, an Israeli Mossad agent, is given the mi...     103
# 10134  Damon Runyon's fairytale, sweet and funny, is ...     136
# 6957   A documentary of the German National soccer te...     107
# 10450  Miss Marple and Mr Stringer are witness to the...      81
# 9891   During an annual board of trustees meeting, on...      93
# ...                                                  ...     ...
# 572    A short film promoting the opening of Melco-Cr...      16
# 528    Unwinding her relationship from a controlling ...      90
# 4797   Christmas Eve, 1892, and the falling snow is t...      60
# 569    When MP's wife Grace Goodwin is found naked on...      90
# 6078   From the director of Bigger Stronger Faster co...     107
#
#                                     genres  \
# 7204                                 Drama
# 10134                         Comedy|Drama
# 6957                           Documentary
# 10450  Drama|Thriller|Crime|Mystery|Comedy
# 9891   Drama|Thriller|Crime|Mystery|Comedy
# ...                                    ...
# 572                                 Comedy
# 528                       Romance|TV Movie
# 4797                                   NaN
# 569                           Drama|Horror
# 6078                           Documentary
#
#                                     production_companies release_date  \
# 7204                        Lama Films|United King Films       2/5/04
# 10134                                 Franton Production     12/18/61
# 6957                     Little Shark Entertainment GmbH      10/3/06
# 10450                          Metro-Goldwyn-Mayer (MGM)       1/1/63
# 9891                           Metro-Goldwyn-Mayer (MGM)       6/1/64
# ...                                                  ...          ...
# 572    RatPac Entertainment|Melco-Crown Entertainment...     10/27/15
# 528                                                  NaN      12/5/15
# 4797                                   BBC Television UK     12/25/12
# 569                                  Bentley Productions     12/27/15
# 6078                                                 NaN      12/4/13
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 7204          10           6.4          2004  1.616224e+06  0.000000e+00
# 10134         10           6.1          1961  2.115510e+07  3.647431e+07
# 6957          10           7.3          2006  0.000000e+00  0.000000e+00
# 10450         10           5.4          1963  0.000000e+00  0.000000e+00
# 9891          10           6.7          1964  0.000000e+00  0.000000e+00
# ...          ...           ...           ...           ...           ...
# 572           10           6.1          2015  0.000000e+00  0.000000e+00
# 528           10           7.6          2015  0.000000e+00  0.000000e+00
# 4797          10           7.8          2012  0.000000e+00  0.000000e+00
# 569           10           5.3          2015  0.000000e+00  0.000000e+00
# 6078          10           7.8          2013  0.000000e+00  0.000000e+00
#
# [501 rows x 21 columns]

# %% [markdown]
# ## Data Cleaning

# %%
# Removing the duplicated movie.
df.drop(index=2090,inplace=True)
# Getting same information about the database to assure that the duplicated movie have been dropped.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10865 entries, 8088 to 3460
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10865 non-null  int64
#  1   imdb_id               10855 non-null  object
#  2   popularity            10865 non-null  float64
#  3   budget                10865 non-null  int64
#  4   revenue               10865 non-null  int64
#  5   original_title        10865 non-null  object
#  6   cast                  10789 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10821 non-null  object
#  9   tagline               8041 non-null   object
#  10  keywords              9372 non-null   object
#  11  overview              10861 non-null  object
#  12  runtime               10865 non-null  int64
#  13  genres                10842 non-null  object
#  14  production_companies  9835 non-null   object
#  15  release_date          10865 non-null  object
#  16  vote_count            10865 non-null  int64
#  17  vote_average          10865 non-null  float64
#  18  release_year          10865 non-null  int64
#  19  budget_adj            10865 non-null  float64
#  20  revenue_adj           10865 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.8+ MB

# %%
# Amendment of the column names
df.rename(columns={'budget_adj':'budget_adjustment'},inplace=True)
df.rename(columns={'revenue_adj':'revenue_adjustment'},inplace=True)
df.head(3)
# Out:
#        id    imdb_id  popularity    budget    revenue  original_title  \
# 8088    5  tt0113101    1.234890   4000000    4300000      Four Rooms
# 10249   6  tt0107286    0.815631         0   12136938  Judgment Night
# 1329   11  tt0076759   12.037933  11000000  775398007       Star Wars
#
#                                                     cast  \
# 8088   Tim Roth|Antonio Banderas|Jennifer Beals|Madon...
# 10249  Emilio Estevez|Cuba Gooding Jr.|Denis Leary|Je...
# 1329   Mark Hamill|Harrison Ford|Carrie Fisher|Peter ...
#
#                                                 homepage  \
# 8088                                                 NaN
# 10249                                                NaN
# 1329   http://www.starwars.com/films/star-wars-episod...
#
#                                                 director  \
# 8088   Allison Anders|Alexandre Rockwell|Robert Rodri...
# 10249                                    Stephen Hopkins
# 1329                                        George Lucas
#
#                                                  tagline  ...  \
# 8088   Twelve outrageous guests. Four scandalous requ...  ...
# 10249     Don't move. Don't whisper. Don't even breathe.  ...
# 1329        A long time ago in a galaxy far, far away...  ...
#
#                                                 overview runtime  \
# 8088   It's Ted the Bellhop's first night on the job....      98
# 10249  While racing to a boxing match, Frank, Mike, J...     110
# 1329   Princess Leia is captured and held hostage by ...     121
#
#                                  genres  \
# 8088                             Comedy
# 10249             Action|Thriller|Crime
# 1329   Adventure|Action|Science Fiction
#
#                                    production_companies release_date  \
# 8088                         Miramax Films|A Band Apart     12/25/95
# 10249    Largo Entertainment|JVC Entertainment Networks     10/15/93
# 1329   Lucasfilm|Twentieth Century Fox Film Corporation      3/20/77
#
#       vote_count  vote_average  release_year  budget_adjustment  \
# 8088         293           6.4          1995       5.723867e+06
# 10249         36           6.4          1993       0.000000e+00
# 1329        4428           7.9          1977       3.957559e+07
#
#        revenue_adjustment
# 8088         6.153158e+06
# 10249        1.832034e+07
# 1329         2.789712e+09
#
# [3 rows x 21 columns]

# %%
# Check how many duplicated patients in this database.
duplicated_imdb_id = df['imdb_id'].duplicated().sum()
print("This database contain the sum of {:,} duplicated imdb id now after dropping the duplicated row.".format(duplicated_imdb_id))
# Out:
# This database contain the sum of 9 duplicated imdb id now after dropping the duplicated row.

# %%
df.head(1)
# Out:
#       id    imdb_id  popularity   budget  revenue original_title  \
# 8088   5  tt0113101     1.23489  4000000  4300000     Four Rooms
#
#                                                    cast homepage  \
# 8088  Tim Roth|Antonio Banderas|Jennifer Beals|Madon...      NaN
#
#                                                director  \
# 8088  Allison Anders|Alexandre Rockwell|Robert Rodri...
#
#                                                 tagline  ...  \
# 8088  Twelve outrageous guests. Four scandalous requ...  ...
#
#                                                overview runtime  genres  \
# 8088  It's Ted the Bellhop's first night on the job....      98  Comedy
#
#             production_companies release_date vote_count  vote_average  \
# 8088  Miramax Films|A Band Apart     12/25/95        293           6.4
#
#       release_year  budget_adjustment  revenue_adjustment
# 8088          1995       5.723867e+06        6.153158e+06
#
# [1 rows x 21 columns]

# %%
# Deleting the 'imdb_id', 'homepage', 'keywords', 'overview', and 'tagline' columns from the database
df = df.drop(columns=['imdb_id', 'homepage', 'keywords', 'overview', 'tagline'])
#now take a look at this new dataset
df.head(1)
# Out:
#       id  popularity   budget  revenue original_title  \
# 8088   5     1.23489  4000000  4300000     Four Rooms
#
#                                                    cast  \
# 8088  Tim Roth|Antonio Banderas|Jennifer Beals|Madon...
#
#                                                director  runtime  genres  \
# 8088  Allison Anders|Alexandre Rockwell|Robert Rodri...       98  Comedy
#
#             production_companies release_date  vote_count  vote_average  \
# 8088  Miramax Films|A Band Apart     12/25/95         293           6.4
#
#       release_year  budget_adjustment  revenue_adjustment
# 8088          1995       5.723867e+06        6.153158e+06

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis

# %% [markdown]
# ### Deviding the data into decades

# %%
# Dividing the movies to multiple groups according to the releasing year during each 10 years.
sixties = df[df['release_year'].between(1960,1969)]
seventies = df[df['release_year'].between(1970,1979)]
eighties = df[df['release_year'].between(1980,1989)]
nineties = df[df['release_year'].between(1990,1999)]
twenties = df[df['release_year'].between(2000,2009)]
tenth = df[df['release_year'].between(2010,2019)]

# %%
# Assuring that the figures are correct.
len(sixties + seventies + eighties + nineties + twenties + tenth) == rows_count - duplicated
# Out:
# True

# %%
decades = {
    'sixties 1960s': len(sixties),
    'seventies 1970s': len(seventies),
    'eighties 1980s': len(eighties),
    'nineties 1990s': len(nineties),
    'twenties 2000s': len(twenties),
    'tenth 2010s': len(tenth)
}
decades_names = ['1960s','1970s','1980s','1990s','2000s','2010s']
decades_values = [len(sixties),len(seventies),len(eighties),len(nineties),len(twenties),len(tenth)]
decades,decades_names,decades_values
# Out:
# ({'sixties 1960s': 362,
#   'seventies 1970s': 508,
#   'eighties 1980s': 1063,
#   'nineties 1990s': 1765,
#   'twenties 2000s': 3562,
#   'tenth 2010s': 3605},
#  ['1960s', '1970s', '1980s', '1990s', '2000s', '2010s'],
#  [362, 508, 1063, 1765, 3562, 3605])

# %%
first_mil = sum(decades_values[0:4])
second_mil = sum(decades_values[4:6])
first_mil_ratio = first_mil / (first_mil + second_mil) * 100
second_mil_ratio = second_mil / (first_mil + second_mil) * 100
print ("During 1900s only around {} movies \
with the ratio of {:.0f}% from all movies in the database.".format(first_mil,first_mil_ratio))
print ("While 1900s movies are during {} years \
with the average of {:,.0f} movies per year.".format(2000-1960,first_mil/(2000-1960)))
print('\n')
print ("During 2000s only around {} movies \
with the ratio of {:.0f}% have been released of all movies in the database.".format(second_mil,second_mil_ratio))
print ("While 2000s movies are during ***ONLY*** {} years\
with the average of {:,.0f} movies per year.".format(2015-2000,second_mil/(2015-2000)))
# Out:
# During 1900s only around 3698 movies with the ratio of 34% from all movies in the database.
# While 1900s movies are during 40 years with the average of 92 movies per year.
#
#
# During 2000s only around 7167 movies with the ratio of 66% have been released of all movies in the database.
# While 2000s movies are during ***ONLY*** 15 yearswith the average of 478 movies per year.

# %%
fig = plt.figure(figsize=(10,7))
plt.pie(decades_values, labels = decades_names)
plt.show()

# %%
def my_format(x):
    print(x)
    return '{:.2f}%\n({:,.0f} Movies)'.format(x, rows_count*x/100)

fig = plt.figure(figsize=(10,7))
plt.pie((first_mil,second_mil), labels = ('1900s','2000s'), colors = ('grey','green'), autopct=my_format)
plt.show()
# Out:
# 34.03589427471161
# 65.96410274505615

# %%
df.release_date = pd.to_datetime(df['release_date'])
df.head(3)
# Out:
#        id  popularity    budget    revenue  original_title  \
# 8088    5    1.234890   4000000    4300000      Four Rooms
# 10249   6    0.815631         0   12136938  Judgment Night
# 1329   11   12.037933  11000000  775398007       Star Wars
#
#                                                     cast  \
# 8088   Tim Roth|Antonio Banderas|Jennifer Beals|Madon...
# 10249  Emilio Estevez|Cuba Gooding Jr.|Denis Leary|Je...
# 1329   Mark Hamill|Harrison Ford|Carrie Fisher|Peter ...
#
#                                                 director  runtime  \
# 8088   Allison Anders|Alexandre Rockwell|Robert Rodri...       98
# 10249                                    Stephen Hopkins      110
# 1329                                        George Lucas      121
#
#                                  genres  \
# 8088                             Comedy
# 10249             Action|Thriller|Crime
# 1329   Adventure|Action|Science Fiction
#
#                                    production_companies release_date  \
# 8088                         Miramax Films|A Band Apart   1995-12-25
# 10249    Largo Entertainment|JVC Entertainment Networks   1993-10-15
# 1329   Lucasfilm|Twentieth Century Fox Film Corporation   1977-03-20
#
#        vote_count  vote_average  release_year  budget_adjustment  \
# 8088          293           6.4          1995       5.723867e+06
# 10249          36           6.4          1993       0.000000e+00
# 1329         4428           7.9          1977       3.957559e+07
#
#        revenue_adjustment
# 8088         6.153158e+06
# 10249        1.832034e+07
# 1329         2.789712e+09

# %% [markdown]
# Cleaning the runtime fields and replace the 0 with NAN to clean the data base.

# %%
#replacing 0 with NaN of runtime column in the dataset
df['runtime'] =df['runtime'].replace(0, np.NAN)

# %% [markdown]
# Cleaning the budget, revenue fields and replace the 0 with NAN and drop the records with null cells to clean the data base.

# %%
# creating a seperate list of revenue and budget column
temp_list=['budget', 'revenue']
df[temp_list] = df[temp_list].replace(0, np.NAN)
df.dropna(subset = temp_list, inplace = True)
rows, col = df.shape
print('So after removing such entries, we now have only {} no.of movies.'.format(rows-1))
# Out:
# So after removing such entries, we now have only 3853 no.of movies.

# %%
df.head(3)
# Out:
#       id  popularity      budget      revenue original_title  \
# 8088   5    1.234890   4000000.0    4300000.0     Four Rooms
# 1329  11   12.037933  11000000.0  775398007.0      Star Wars
# 4955  12    3.440519  94000000.0  864625978.0   Finding Nemo
#
#                                                    cast  \
# 8088  Tim Roth|Antonio Banderas|Jennifer Beals|Madon...
# 1329  Mark Hamill|Harrison Ford|Carrie Fisher|Peter ...
# 4955  Albert Brooks|Ellen DeGeneres|Alexander Gould|...
#
#                                                director  runtime  \
# 8088  Allison Anders|Alexandre Rockwell|Robert Rodri...     98.0
# 1329                                       George Lucas    121.0
# 4955                         Andrew Stanton|Lee Unkrich    100.0
#
#                                 genres  \
# 8088                            Comedy
# 1329  Adventure|Action|Science Fiction
# 4955                  Animation|Family
#
#                                    production_companies release_date  \
# 8088                         Miramax Films|A Band Apart   1995-12-25
# 1329   Lucasfilm|Twentieth Century Fox Film Corporation   1977-03-20
# 4955  Walt Disney Pictures|Pixar Animation Studios|D...   2003-05-30
#
#       vote_count  vote_average  release_year  budget_adjustment  \
# 8088         293           6.4          1995       5.723867e+06
# 1329        4428           7.9          1977       3.957559e+07
# 4955        3692           7.4          2003       1.114231e+08
#
#       revenue_adjustment
# 8088        6.153158e+06
# 1329        2.789712e+09
# 4955        1.024887e+09

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Calculating the profit of the each movie

# %%
#insert function with three parameters(index of the column in the dataset, name of the column, value to be inserted)
df.insert(4,'profit_earned',df['revenue']-df['budget'])

#previewing the changes in the dataset
df.head(2)
# Out:
#       id  popularity      budget      revenue  profit_earned original_title  \
# 8088   5    1.234890   4000000.0    4300000.0       300000.0     Four Rooms
# 1329  11   12.037933  11000000.0  775398007.0    764398007.0      Star Wars
#
#                                                    cast  \
# 8088  Tim Roth|Antonio Banderas|Jennifer Beals|Madon...
# 1329  Mark Hamill|Harrison Ford|Carrie Fisher|Peter ...
#
#                                                director  runtime  \
# 8088  Allison Anders|Alexandre Rockwell|Robert Rodri...     98.0
# 1329                                       George Lucas    121.0
#
#                                 genres  \
# 8088                            Comedy
# 1329  Adventure|Action|Science Fiction
#
#                                   production_companies release_date  \
# 8088                        Miramax Films|A Band Apart   1995-12-25
# 1329  Lucasfilm|Twentieth Century Fox Film Corporation   1977-03-20
#
#       vote_count  vote_average  release_year  budget_adjustment  \
# 8088         293           6.4          1995       5.723867e+06
# 1329        4428           7.9          1977       3.957559e+07
#
#       revenue_adjustment
# 8088        6.153158e+06
# 1329        2.789712e+09

# %% [markdown]
# ### Creating a new function to calculate the highest and lowest values
# for a specific column and get the records in vertical view

# %%
import pprint
#defining the function
def calculate(column):
    #The highest profit
    high= df[column].idxmax()
    high_details=pd.DataFrame(df.loc[high])
    
    #the highest loss
    low= df[column].idxmin()
    low_details=pd.DataFrame(df.loc[low])
    
    #collectin data in one place
    info=pd.concat([high_details, low_details], axis=1)
    
    return info

# %% [markdown]
# ### Movies which had most and least profit

# %% [markdown]
# Trying the Calculate function for Profit Earned Column

# %%
#calling the function
calculate('profit_earned')
# Out:
#                                                                    1386  \
# id                                                                19995
# popularity                                                     9.432768
# budget                                                      237000000.0
# revenue                                                    2781505847.0
# profit_earned                                              2544505847.0
# original_title                                                   Avatar
# cast                  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# director                                                  James Cameron
# runtime                                                           162.0
# genres                         Action|Adventure|Fantasy|Science Fiction
# production_companies  Ingenious Film Partners|Twentieth Century Fox ...
# release_date                                        2009-12-10 00:00:00
# vote_count                                                         8458
# vote_average                                                        7.1
# release_year                                                       2009
# budget_adjustment                                      240886902.887613
# revenue_adjustment                                     2827123750.41189
#
#                                                                    2244
# id                                                                46528
# popularity                                                      0.25054
# budget                                                      425000000.0
# revenue                                                      11087569.0
# profit_earned                                              -413912431.0
# original_title                                        The Warrior's Way
# cast                  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...
# director                                                     Sngmoo Lee
# runtime                                                           100.0
# genres                        Adventure|Fantasy|Action|Western|Thriller
# production_companies                           Boram Entertainment Inc.
# release_date                                        2010-12-02 00:00:00
# vote_count                                                           74
# vote_average                                                        6.4
# release_year                                                       2010
# budget_adjustment                                           425000000.0
# revenue_adjustment                                           11087569.0

# %% [markdown]
# **"Avatar"** Movie shows the highest profit of around 2,544.5M, While **"The Warrior's Way"** Movie shows the loss of around 414M.

# %% [markdown]
# ### Movies with largest and lowest budgets

# %%
# we will call the same function **calculate(column)** again for this analysis
calculate('budget')
# Out:
#                                                                    2244  \
# id                                                                46528
# popularity                                                      0.25054
# budget                                                      425000000.0
# revenue                                                      11087569.0
# profit_earned                                              -413912431.0
# original_title                                        The Warrior's Way
# cast                  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...
# director                                                     Sngmoo Lee
# runtime                                                           100.0
# genres                        Adventure|Fantasy|Action|Western|Thriller
# production_companies                           Boram Entertainment Inc.
# release_date                                        2010-12-02 00:00:00
# vote_count                                                           74
# vote_average                                                        6.4
# release_year                                                       2010
# budget_adjustment                                           425000000.0
# revenue_adjustment                                           11087569.0
#
#                                                                    2618
# id                                                                39964
# popularity                                                     0.090186
# budget                                                              1.0
# revenue                                                           100.0
# profit_earned                                                      99.0
# original_title                                             Lost & Found
# cast                  David Spade|Sophie Marceau|Ever Carradine|Step...
# director                                                   Jeff Pollack
# runtime                                                            95.0
# genres                                                   Comedy|Romance
# production_companies           Alcon Entertainment|Dinamo Entertainment
# release_date                                        1999-04-23 00:00:00
# vote_count                                                           14
# vote_average                                                        4.8
# release_year                                                       1999
# budget_adjustment                                              1.309053
# revenue_adjustment                                           130.905285

# %% [markdown]
# **"The Warrior's Way"** have the largest budget of **425,000,000** dollar, while **"Lost & Found"** shows the smallest budget of **1** dollar.

# %% [markdown]
# ### Movies with most and least earned revenue

# %%
# we will call the same function **calculate(column)** again for this analysis
calculate('revenue')
# Out:
#                                                                    1386  \
# id                                                                19995
# popularity                                                     9.432768
# budget                                                      237000000.0
# revenue                                                    2781505847.0
# profit_earned                                              2544505847.0
# original_title                                                   Avatar
# cast                  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# director                                                  James Cameron
# runtime                                                           162.0
# genres                         Action|Adventure|Fantasy|Science Fiction
# production_companies  Ingenious Film Partners|Twentieth Century Fox ...
# release_date                                        2009-12-10 00:00:00
# vote_count                                                         8458
# vote_average                                                        7.1
# release_year                                                       2009
# budget_adjustment                                      240886902.887613
# revenue_adjustment                                     2827123750.41189
#
#                                                                    8142
# id                                                                 2293
# popularity                                                     0.552091
# budget                                                        6000000.0
# revenue                                                             2.0
# profit_earned                                                -5999998.0
# original_title                                                 Mallrats
# cast                  Jason Lee|Jeremy London|Shannen Doherty|Claire...
# director                                                    Kevin Smith
# runtime                                                            94.0
# genres                                                   Romance|Comedy
# production_companies  Gramercy Pictures|Alphaville Films|View Askew ...
# release_date                                        1995-10-20 00:00:00
# vote_count                                                          201
# vote_average                                                        6.8
# release_year                                                       1995
# budget_adjustment                                        8585801.202642
# revenue_adjustment                                             2.861934

# %% [markdown]
# **"Avatar"** have the largest revenue, while **"Mallrats"** is the lowest.

# %% [markdown]
# ### Movies with highest and lowest vote counts

# %%
calculate('vote_count')
# Out:
#                                                                   1919   \
# id                                                                27205
# popularity                                                     9.363643
# budget                                                      160000000.0
# revenue                                                     825500000.0
# profit_earned                                               665500000.0
# original_title                                                Inception
# cast                  Leonardo DiCaprio|Joseph Gordon-Levitt|Ellen P...
# director                                              Christopher Nolan
# runtime                                                           148.0
# genres                Action|Thriller|Science Fiction|Mystery|Adventure
# production_companies            Legendary Pictures|Warner Bros.|Syncopy
# release_date                                        2010-07-14 00:00:00
# vote_count                                                         9767
# vote_average                                                        7.9
# release_year                                                       2010
# budget_adjustment                                           160000000.0
# revenue_adjustment                                          825500000.0
#
#                                                                   10134
# id                                                                  248
# popularity                                                     0.290285
# budget                                                        2900000.0
# revenue                                                       5000000.0
# profit_earned                                                 2100000.0
# original_title                                    Pocketful of Miracles
# cast                  Glenn Ford|Bette Davis|Hope Lange|Arthur O'Con...
# director                                                    Frank Capra
# runtime                                                           136.0
# genres                                                     Comedy|Drama
# production_companies                                 Franton Production
# release_date                                        2061-12-18 00:00:00
# vote_count                                                           10
# vote_average                                                        6.1
# release_year                                                       1961
# budget_adjustment                                       21155097.503115
# revenue_adjustment                                      36474306.039853

# %% [markdown]
# Most voted movie is **'Inception'** and the least is **'Pocketful of Miracles'** while there are *another 500 records with the same value of 10 votes* only as above we mentioned.

# %% [markdown]
# ### Calculating the highest and lowest vote average

# %%
calculate('vote_average')
# Out:
#                                                                    4178  \
# id                                                                  278
# popularity                                                     7.192039
# budget                                                       25000000.0
# revenue                                                      28341469.0
# profit_earned                                                 3341469.0
# original_title                                 The Shawshank Redemption
# cast                  Tim Robbins|Morgan Freeman|Bob Gunton|William ...
# director                                                 Frank Darabont
# runtime                                                           142.0
# genres                                                      Drama|Crime
# production_companies                          Castle Rock Entertainment
# release_date                                        1994-09-10 00:00:00
# vote_count                                                         5754
# vote_average                                                        8.4
# release_year                                                       1994
# budget_adjustment                                       36777789.039954
# revenue_adjustment                                      41693462.718576
#
#                                                                    4859
# id                                                               116977
# popularity                                                     0.111351
# budget                                                       65000000.0
# revenue                                                         73706.0
# profit_earned                                               -64926294.0
# original_title                                               Foodfight!
# cast                  Charlie Sheen|Wayne Brady|Hilary Duff|Eva Long...
# director                                              Lawrence Kasanoff
# runtime                                                            87.0
# genres                                   Animation|Action|Comedy|Family
# production_companies  Threshold Entertainment|Lions Gate Family Ente...
# release_date                                        2012-06-15 00:00:00
# vote_count                                                           12
# vote_average                                                        2.2
# release_year                                                       2012
# budget_adjustment                                       61733378.287896
# revenue_adjustment                                         70001.852001

# %% [markdown]
# The top voted movie is **'The Shawshank Redemption'** which is rated **8.4** and the least voted is **'Foodfight'** movie rated  only **2.2**.

# %% [markdown]
# ### Movies with longest and shortest runtime

# %%
calculate('runtime')
# Out:
#                                                                    2107  \
# id                                                                43434
# popularity                                                     0.534192
# budget                                                       18000000.0
# revenue                                                        871279.0
# profit_earned                                               -17128721.0
# original_title                                                   Carlos
# cast                  Edgar RamÃ­rez|Alexander Scheer|Fadi Abi Samra...
# director                                                Olivier Assayas
# runtime                                                           338.0
# genres                                     Crime|Drama|Thriller|History
# production_companies  Egoli Tossell Film AG|Canal+|Arte France|Films...
# release_date                                        2010-05-19 00:00:00
# vote_count                                                           35
# vote_average                                                        6.2
# release_year                                                       2010
# budget_adjustment                                            18000000.0
# revenue_adjustment                                             871279.0
#
#                                                                    5162
# id                                                                24914
# popularity                                                     0.208637
# budget                                                             10.0
# revenue                                                             5.0
# profit_earned                                                      -5.0
# original_title                                              Kid's Story
# cast                  Clayton Watson|Keanu Reeves|Carrie-Anne Moss|K...
# director                                            Shinichiro Watanabe
# runtime                                                            15.0
# genres                                        Science Fiction|Animation
# production_companies                                        Studio 4Â°C
# release_date                                        2003-06-02 00:00:00
# vote_count                                                           16
# vote_average                                                        6.8
# release_year                                                       2003
# budget_adjustment                                             11.853526
# revenue_adjustment                                             5.926763

# %% [markdown]
# **"Carlos"** Movie shows the longest runtime **338 minutes**, while **"Kid's Story"** shows the shortest runtime **15 minutes**.

# %% [markdown]
# ### Average runtime of the movies

# %%
# defining a function to find average of any column
def avg_fun(column):
    return df[column].mean()
avg_fun('runtime')
# Out:
# 109.22029060716139

# %% [markdown]
# So the average runtime a movie is around **109 minutes**.

# %% [markdown]
# #### Analyzing the duration of the movies

# %%
# Creating a Plot of runtime of all movies
plt.figure(figsize=(16,5))
plt.xlabel('Duration of the Movies')
plt.ylabel('Count of Movies in the Database')
plt.title('Duration of all movies')
plt.hist(df['runtime'], rwidth = 0.9, bins =35)
plt.show()

# %% [markdown]
# The analysis shows that the most movies duration are around 90 to 110 minutes.

# %% [markdown]
# ### Year of release vs Profitability

# %%
# Profit vs year of release
profits_year = df.groupby('release_year')['profit_earned'].sum()
plt.figure(figsize=(16,6))
plt.xlabel('Release Year')
plt.ylabel('Profit')
plt.title('Total Profits earned by all movies for each releasing year')
plt.plot(profits_year)
plt.show()

# %% [markdown]
# The profit ears are going higher with time as you can see in the above graph.

# %% [markdown]
# ### The most profit year

# %%
#Which year made the highest profit?
profits_year.idxmax()
# Out:
# 2015

# %% [markdown]
# ### The least profit year

# %%
profits_year.idxmin()
# Out:
# 1966

# %% [markdown]
# The most profit year is 2015 and the least is 1966.

# %% [markdown]
# ### Movies with 50M or more profit.

# %%
#selecting the movies having profit $50M or more
profit_data = df[df['profit_earned'] >= 50000000]
profit_data.index = range(len(profit_data))
profit_data.index = profit_data.index + 1
profit_data.head(3)
# Out:
#    id  popularity      budget      revenue  profit_earned original_title  \
# 1  11   12.037933  11000000.0  775398007.0    764398007.0      Star Wars
# 2  12    3.440519  94000000.0  864625978.0    770625978.0   Finding Nemo
# 3  13    6.715966  55000000.0  677945399.0    622945399.0   Forrest Gump
#
#                                                 cast  \
# 1  Mark Hamill|Harrison Ford|Carrie Fisher|Peter ...
# 2  Albert Brooks|Ellen DeGeneres|Alexander Gould|...
# 3  Tom Hanks|Robin Wright|Gary Sinise|Mykelti Wil...
#
#                      director  runtime                            genres  \
# 1                George Lucas    121.0  Adventure|Action|Science Fiction
# 2  Andrew Stanton|Lee Unkrich    100.0                  Animation|Family
# 3             Robert Zemeckis    142.0              Comedy|Drama|Romance
#
#                                 production_companies release_date  vote_count  \
# 1   Lucasfilm|Twentieth Century Fox Film Corporation   1977-03-20        4428
# 2  Walt Disney Pictures|Pixar Animation Studios|D...   2003-05-30        3692
# 3                                 Paramount Pictures   1994-07-06        4856
#
#    vote_average  release_year  budget_adjustment  revenue_adjustment
# 1           7.9          1977       3.957559e+07        2.789712e+09
# 2           7.4          2003       1.114231e+08        1.024887e+09
# 3           8.1          1994       8.091114e+07        9.973333e+08

# %% [markdown]
# #### A new function which will split the data in each cell

# %%
def data(column):
    data = profit_data[column].str.cat(sep = '|')
    data = pd.Series(data.split('|'))
    count = data.value_counts(ascending = False)
    return count

# %% [markdown]
# ### Succesful Production Companies

# %%
#variable to store the retured value
count = data('production_companies')
count.head(10)
# Out:
# Universal Pictures                        156
# Warner Bros.                              144
# Paramount Pictures                        130
# Twentieth Century Fox Film Corporation    118
# Columbia Pictures                          93
# Walt Disney Pictures                       78
# New Line Cinema                            67
# Columbia Pictures Corporation              51
# Relativity Media                           50
# Touchstone Pictures                        46
# dtype: int64

# %%
ax = count.iloc[:20].plot(kind="barh")
ax.set(title = 'Top 20 Production Companies in Profitable Movies')
ax.set_xlabel('Count of Movies in the database')
ax.figure.set_size_inches(16, 8)
ax.invert_yaxis()

# %% [markdown]
# ### Succesful Director

# %%
#variable to store the retured value
count = data('director')
count.head(10)
# Out:
# Steven Spielberg    23
# Robert Zemeckis     13
# Clint Eastwood      12
# Tim Burton          11
# Tony Scott          10
# Ron Howard          10
# Ridley Scott        10
# Michael Bay          9
# David Fincher        8
# Roland Emmerich      8
# dtype: int64

# %%
ax = count.iloc[:20].plot(kind="barh")
ax.set(title = 'Top 20 Directors in Profitable Movies')
ax.set_xlabel('Count of Movies in the database')
ax.figure.set_size_inches(16, 8)
ax.invert_yaxis()

# %% [markdown]
# ### Succesful Genres

# %%
#variable to store the retured value
count = data('genres')
count.head(10)
# Out:
# Comedy             492
# Drama              481
# Action             464
# Thriller           405
# Adventure          379
# Family             229
# Romance            215
# Science Fiction    206
# Fantasy            201
# Crime              193
# dtype: int64

# %%
#Create a descending order plot for genres from top to bottom
count.sort_values(ascending = True, inplace = True)
lt = count.plot.barh()
lt.set(title = 'Most Genres in Profitable Movies')
lt.set_xlabel('Count of Movies in the database', color = 'black')
lt.figure.set_size_inches(16, 8)
plt.show()

# %% [markdown]
# ### Most Frequent Star

# %%
#variable to store the retured value
count = data('cast')
count.head(10)
# Out:
# Tom Cruise            27
# Brad Pitt             25
# Tom Hanks             22
# Sylvester Stallone    21
# Cameron Diaz          20
# Jim Carrey            19
# Denzel Washington     19
# Robert De Niro        19
# Adam Sandler          19
# Bruce Willis          19
# dtype: int64

# %%
ax = count.iloc[:20].plot(kind="barh")
ax.set(title = 'Top 20 Stars in Profitable Movies')
ax.set_xlabel('Count of Movies in the database')
ax.figure.set_size_inches(16, 8)
ax.invert_yaxis()

# %%
#plots the data points of runtime of movies

#giving figure size
plt.figure(figsize=(10,5), dpi = 105)

sns.swarmplot(df['runtime'], color = 'grey')
plt.show()
# Out:
# C:\Users\WiSHa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\WiSHa\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 72.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions

# %% [markdown]
# <ul>
# <li>The movies production is moving forward and every year we release more movies than the last year.</li>
# <li>Taken Movie is recorded twice.</li>
# <li>Minimal records without Cast, director, overview, or generes.</li>
# <li>Too many records without homepage, tagline, keywords, or production companies</li>
# <li>Inception is the most movie voted for with the count of 9,767 votes.</li>
# <li>The least voted movies are 501 movies with only 10 votes each.</li>
# <li>During 1900s only around 3698 movies with the ratio of 34% from all movies in the database, While 1900s movies are during 40 years with the average of 92 movies per year.</li>
# <li>During 2000s only around 7167 movies with the ratio of 66% have been released of all movies in the database, While 2000s movies are during ***ONLY*** 15 years with the average of 478 movies per year.</li>
# <li>"Avatar" Movie shows the highest profit of around 2,544.5M, While "The Warrior's Way" Movie shows the loss of around 414M.</li>
# <li>"The Warrior's Way" have the largest budget of 425,000,000 dollar, while "Judgment Night" shows the smallest budget of 0 dollar.</li>
# <li>"Avatar" have the largest revenue, while "Mallrats" is the lowest.</li>
# <li>"Carlos" Movie shows the longest runtime 338 minutes, while "Kid's Story" shows the shortest runtime 15 minutes.</li>
# <li>So the average runtime a movie is 109 minutes.</li>
# <li>The average duration of the movies is around 100 minutes or mostly less by some little minutes.</li>
# <li>The highest profit was in 2015, which is the last year in the existing database and the least was in 1966.</li>
# <li>Star Wars, Finding Nemo, and Forrest Gump have 50M profit or more.</li>
# <li>The most used genre is Comedy.</li>
# <li>Most frequent star is Tom Cruise.</li>
# </ul>
